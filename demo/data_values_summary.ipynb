# %%
import pandas as pd
import numpy as np

# %%
import pyandev
from pyandev.tests import data as test_data

# %%
pyandev.__version__
# Out:
# '0.1.0'

# %%
dir(pyandev)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'data_summary',
#  'data_values_summary',
#  'discretisation',
#  'plot',
#  'tests']

# %%
boston_df = test_data.load_boston_df(insert_missings = True)

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0    NaN   0.0  0.538    NaN  65.2  4.0900  1.0  296.0
# 1  0.02731   NaN   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2      NaN   NaN   7.07   0.0    NaN  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   NaN  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83    NaN    34.7
# 3     18.7     NaN   2.94    33.4
# 4     18.7  396.90    NaN    36.2

# %%
pyandev.data_values_summary.data_values_summary(boston_df)
# Out:
#     CRIM_value CRIM_count  ZN_value ZN_count  INDUS_value INDUS_count  \
# 0      0.00632          1       0.0      331         0.46           1
# 1      0.00906          1      12.5        9         0.74           1
# 2      0.01096          1      17.5        1         1.21           1
# 3      0.01301          1      18.0        1         1.22           1
# 4      0.01311          1      20.0       19         1.25           2
# 5          NaN       None      21.0        2          NaN        None
# 6      0.24980          1      22.0        9         4.15           1
# 7      0.25199          1      25.0       10         4.39           2
# 8      0.25356          1      28.0        3         4.49           4
# 9      0.25387          1      30.0        6         4.86           4
# 10     0.25915          1      33.0        2         4.93           6
# 11     0.26363          1      34.0        2         4.95           2
# ...
